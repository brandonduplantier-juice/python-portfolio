# %% [markdown]
# ![](https://media.giphy.com/media/14at0w5LpT5zW0/giphy.gif)

# %%
simpsons = [
  'Homer Simpson', 
  'Marge Simpson',   
  'Bart Simpson', 
  'Lisa Simpson', 
  'Maggie Simpson', 
  'Grampa Simpson',   
  'Montgomery Burns', 
  'Ned Flanders',          
  'Krusty the Clown',
  'Nelson Muntz',       
  'Sideshow Bob',     
  'Waylon Smithers',    
  'Principal Skinner',
  'Moe Szyslak', 
  'Ralph Wiggum',          
  'Barney Gumble', 
  'Apu Nahasapeemapetilon',         
  'Lenny Leonard',
  'Carl Carlson',     
  'Chief Wiggum',       
  'Groundskeeper Willie',            
  'Milhouse Van Houten', 
  'Edna Krabappel'
  ]

# %%
# demonstration of indexing

# %%
# demonstration of slicing

# %%
# slicing with an no value on one side of the colon begins or ends from the given value

# %%
# negative indexing counts off from the right side of the list
