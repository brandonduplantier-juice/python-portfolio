# %%
# import data
import sys
sys.path.append('./files')

from sb2_global_sales import markets, sales, sales_idx_na, sales_idx_eu, sales_idx_apac

# %% [markdown]
# ## Debugging

# %% [markdown]
# ### Part 1: Reviewing the Data

# %%
# Slicing error. Instead of the first ten items, returns items 2 through 9

# %%
# Fixes slicing error. Now returns the first ten items
# The zero can be omitted if slicing from the beginning of a list

# %% [markdown]
# ### Part 2: Percentage of Customers from each Market

# %%
# Code in the for loop is indented improperly or missing colon
total_purchases = len(markets)
market_names = ['NA','EU','APAC']

# %% [markdown]
# ### Part 3: Percentage of Sales Amount from the North American Market

# %%
# total_sales
total_sales = sum(sales)

# %%
# total_sales_na should be initialized outside the for loop
