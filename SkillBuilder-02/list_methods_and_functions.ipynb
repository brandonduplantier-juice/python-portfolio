# %% [markdown]
# ## Dataset
#
# Daily high temperatures (in Celsius) in Paris, France from September 2019
#
# ![](https://media.giphy.com/media/vQBkSwVkEZfTq/giphy.gif)

# %%
temperatures = [22, 22, 23, 24, 18, 20, 19,
                18, 18, 22, 23, 23, 23, 25,
                26, 26, 21, 19, 19, 23, 27,
                22, 20, 20, 18, 20, 20, 19,
                20, 18]

# %%
site_visits = ['Champs-Élysées', 'Notre Dame', 'Palace of Versailles',
               'Montmartre', 'Arc de Triomphe', 'Champs-Élysées',
               'Luxembourg Gardens', 'Eiffel Tower']

# %% [markdown]
# ## Part 1: List Functions

# %%
# len function

# %%
# sum function

# %%
# min / max functions

# %% [markdown]
# ## Part 2: List Methods

# %%
# .append method

# %%
# .count method

# %%
# .index method

# %%
# python can give us documentation on a function
