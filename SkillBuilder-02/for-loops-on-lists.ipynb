# %% [markdown]
# # FOR Loops on Lists

# %% [markdown]
# ## Part I: Converting from Celsius to Farenheit
#
# Below, you'll find a list called `temperatures` of the daily high temperatures (in Celsius) in Paris, France from September 2019.

# %%
temperatures = [22, 22, 23, 24, 18, 20, 19,
                18, 18, 22, 23, 23, 23, 25,
                26, 26, 21, 19, 19, 23, 27,
                22, 20, 20, 18, 20, 20, 19,
                20, 18]

# %% [markdown]
# Create a new list of temperatures where these highs have been converted into units of Fahrenheit.
#
# > F = C * 9 / 5 + 32
#
# For example, 20 Celsius corresponds with 20 * 9 / 5 + 32 = 68 Fahrenheit.

# %% [markdown]
# ## Part II: Fun with FOR Loops
# Bootylicious begins with the lyrics:
# > Kelly, can you handle this?<br/>
# > Michelle, can you handle this?<br/>
# > Beyoncé, can you handle this?<br/>
# > I don't think they can handle this!
#
# Using the list of Destiny's Child members' names (`names`), and a `for` loop, print out these lyrics!

# %% [markdown]
# A later part of the song has the following lyrics:
# > Baby, can you handle this?<br/>
# > Baby, can you handle this?<br/>
# > Baby, can you handle this?<br/>
# > I don't you can handle this!
#
# Next, use the `range()` function with a `for` loop to print out this part of Bootylicious.
