# %% [markdown]
# ## Applied Lesson
#
# Sales information for Sweaty Betty has been provided to you in two lists:
#
# - **markets** - Each purchase's source market is given as an abbreviation for North America (NA), Europe (EU), or Asia-Pacific (APAC).
# - **sales** - The amount, in USD, of each purchase made.
#
# Additionally, three helper lists have been provided: **sales_idx_na**, **sales_idx_eu**, and **sales_idx_apac**, with the list indices from **markets** and **sales** that correspond with each region matching the last part of each prompt.

# %%
# import data
import sys
sys.path.append('./files')

from sb2_global_sales import markets, sales, sales_idx_na, sales_idx_eu, sales_idx_apac

# %% [markdown]
# ### Reviewing the Data

# %% [markdown]
# ### Percentage of Customers from each Market

# %% [markdown]
# ### Percentage of Sales Amount from each Market

# %% [markdown]
# ### Level Up: Numeric Formatting for F-strings
