# %% [markdown]
# # Functions and Methods: Numbers

# %% [markdown]
# We have a series of scores from our bowling friend:
#
# > 135, 157, 96, 112, 168, 123
#
# Are they are good enough bowler to be deemed a professional? What is their average score, their lowest score, and highest score?
