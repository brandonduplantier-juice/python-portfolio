# %%
# import data
import sys
sys.path.append('./files')

from customer_data_file import customer_data

# %% [markdown]
# ## Problem
#
# The variable `customer_data` contains data from a small business based in the Pacific Northwest. It is constructed as a dictionary where keys are customer IDs and values are a list with two elements:
# - Index 0: total amount spent by the customer, in dollars
# - Index 1: two-letter state abbreviation from the customer's shipping address
#
# The company wants to run a promotion for their best customers in their home state of Oregon. Retrieve a list of customer IDs that match the criteria of at least \$1,000 spent and a shipping address in Oregon.

# %% [markdown]
# ### Inspecting the Data

# %%
customer_data

# %% [markdown]
# Data looks like the following (for reference)
#
# ```
# customer_data = {
#  'abfdedd9': [1501, 'UT'],
#  '0a10d7a2': [871, 'CA'],
#  'dfab84c9': [1294, 'NV'],
#  '7b812926': [1538, 'ID'],
#  'bc2f7787': [1118, 'OR'],
#  '859ce8fc': [1303, 'CA'],
#  'b2a846a0': [793, 'CA'],
#  '36a8d02e': [1165, 'WA'],
#  '19d59e18': [990, 'OR'],
#  '832d4ab8': [891, 'OR'],
#  '2a3f8992': [794, 'CA'],
#  '2a4603b8': [803, 'OR'],
#  '48826db5': [1098, 'CA'],
#  '813e4348': [1383, 'UT']}
# ```

# %%
# Review how to access elements of a dictionary with multiple values

# %% [markdown]
# ### Solving the Problem
#
# - Write comments to describe the flow of your solution
# - Then write code to complete the flow!

# %%
# for each customer:

# check if their spending is > $1000 and they're from Oregon
# if so, record their ID value
# store ID in a list to send to manager

# %%
# set up list for matching customer ids


# loop through dictionary values


# show list details
