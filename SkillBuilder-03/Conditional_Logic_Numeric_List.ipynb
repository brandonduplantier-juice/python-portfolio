# %% [markdown]
# ## Problem
#
# Below is a list of numbers representing ages for a group trip to an amusement park. Let's prepare the group for the trip by calculating the total ticket price they should expect to pay to enter:
#
# - General admission for adults age 18 or older is \$65.
# - Discounted admission for children ages between 4 and 17 is \$45.
# - Children ages 3 or younger get in free!

# %%
ages = [67, 65, 42, 39, 12, 8, 33, 32, 6, 3, 24, 44, 41, 18, 40, 38, 17, 5, 9]

# %% [markdown]
# ### Conditional Logic with Numbers
#
# The following operators are commonly used to compare numeric values to one another:
#
# - `==`: True if the values on both sides are equal, False otherwise. Take care not to confuse this with the assignment operator `=`.
# - `!=`: True if the values on both sides are not equal, False otherwise.
# - `>`: True if the value on the left is greater than the value on the right, False otherwise.
# - `<`: True if the value on the left is smaller than the value on the right, False otherwise.
# - `>=`: True if the value on the left is greater than or equal to the value on the right, False otherwise.
# - `<=`: True if  the value on the left is smaller than the value on the right, False otherwise.

# %%
sample = [13, 18, 25]

# Test out some comparison operations!

# %% [markdown]
# ### Solving the problem
#
# What do we need:
# - a variable for `total_cost` that we will use to track our prices
# - a `for` loop to iterate through every age in our list
# - check if the user is over 18
#   - if so add \$65 to the `total_cost`
# - check if the user is between 4 and 17
#   - if so add \$45 to the `total_cost`
# - check if the user is less than 3 years old
#   - if so add \$0 to the `total_cost`
#
# - Write comments to describe the flow of your solution
# - Then write code to complete the flow!
