# %%
# import data
import sys
sys.path.append('./files')

from ws_winners import ws_winners

# %% [markdown]
# ## Problem
#
# Stored in the `ws_winners` dictionary are World Series years and their winning teams. Keys are the years, and values are the winning teams.
#
# Q1: How many World Series titles have been won by the New York Yankees?
#
# Q2: How many World Series titles have been won by the New York Yankees or the Boston Red Sox?

# %%
# Show the winner of the 2020 World Series

# %% [markdown]
# ### Iterating over Dictionaries
#
# It is possible to iterate over dictionaries in a `for` loop; each loop pulls out a key from the dictionary.

# %%
# iterate over the dictionary

# %% [markdown]
# ### Solving the Problem
#
# - Write comments to describe the flow of your solution
# - Then write code to complete the flow!
#
# #### Q1: New York Yankees wins

# %%
# Set up a counter variable


# Loop over the dictionary


    # increase win count if winner was the Yankees


# Print the final win count

# %% [markdown]
# #### Q2: Yankees or Red Sox wins

# %%
# set up a counter variable
n_wins = 0

# loop over the dictionary years
    # add tally if winner was the Yankees or Red Sox


# print the final win count
