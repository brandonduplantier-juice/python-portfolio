# %% [markdown]
# # LiveLab | Marketing at Headspace
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## Load the Data
# The data we'll be working with come in the form of three different dictionaries. We'll focus first on just `free_members` and `premium_members`.
#
#
# `free_members` is a dictionary whose keys are:
#   - `user_id`,
#   - `registration_date`,
#   - `registration_platform`,
#   - `acquisition_type`,
#   - `first_free_trial_start_date`,
#   - `first_free_trial_end_date`,
#   - `trial_length`,
#   - and `membership_type`
#
#   The corresponding values are lists. In other words:
#   - `free_members['user_id']` is a list containing all the user_ids for users with a free Headspace membership
#   - `free_members['registration_date']` is a list containing values that indicate the date the user registered for Headspace
#   - `free_members['trial_length']` is a list containing values that indicate length of the free trial for each user on a free membership.
#
#
# `premium_members` is a dictionary set up in the same way, containing the same information, but for users with a premium Headspace membership.
#
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> To load the data into your notebook, run the following cell!
#   </span>
# </div>

# %% [markdown]
# ## Load the Data
# The data we'll be working with come in the form of three different dictionaries. We'll focus first on just `free_members` and `premium_members`.
#
#
# `free_members` is a dictionary whose keys are:
#   - `user_id`,
#   - `registration_date`,
#   - `registration_platform`,
#   - `acquisition_type`,
#   - `first_free_trial_start_date`,
#   - `first_free_trial_end_date`,
#   - `trial_length`,
#   - and `membership_type`
#
#   The corresponding values are lists. In other words:
#   - `free_members['user_id']` is a list containing all the user_ids for users with a free Headspace membership
#   - `free_members['registration_date']` is a list containing values that indicate the date the user registered for Headspace
#   - `free_members['trial_length']` is a list containing values that indicate length of the free trial for each user on a free membership.
#
#
# `premium_members` is a dictionary set up in the same way, containing the same information, but for users with a premium Headspace membership.
#
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> To load the data into your notebook, run the following cell!
#   </span>
# </div>

# %%
# Load the data and import libraries
import sys
sys.path.append('./files')
import headspace

free_members, premium_members, all_members = headspace.initialize()

# %% [markdown]
# ## Task 1: Explore
#
# As a warm up, let's explore the Headspace data and understand how the dictionaries `free_members` and `premium_members` store data.

# %%
# Access data in the free_members dictionary

# %% [markdown]
# Since the marketing team at Headspace is primarily interested in the breakdown of "free" members and "premium" members, we'll be sure to see just how many "free" and "premium" members we have in the data.

# %%
# How many "free" members are in the free_members dictionary?
n_free_members =

# How many "premium" members are in the premium_members dictionary?
n_premium_members =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 # Calculate number of free members
# ----> 2 n_free_members = len(free_members['user_id'])
#       4 # Calculate average trial length for free members
#       5 avg_trial_length_free = sum(free_members['trial_length']) / n_free_members
#
# NameError: name 'free_members' is not defined

# %% [markdown]
# ## Task 2: Trial Length
#
# Here's the scenario: the marketing team at Headspace wants to understand how trial length influences customer behavior and engagement for free versus premium members. Let's wrangle the data to investigate.

# %% [markdown]
# We'll be looking at the *average* trial length of free members and premium members to provide some useful insights on customer behavior and engagement.

# %%
# For all "free" members, calculate the average trial length
avg_trial_length_free =

# Print to the screen


# Repeat for "premium members"
avg_trial_length_premium =

# Print to the screen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 # Calculate number of free members
# ----> 2 n_free_members = len(free_members['user_id'])
#       4 # Calculate average trial length for free members
#       5 avg_trial_length_free = sum(free_members['trial_length']) / n_free_members
#
# NameError: name 'free_members' is not defined

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> The average trial length for Headspace users with a "free" membership is X days, while for "premium" members it's Y days. Why do you think there's such a big difference in trial length between the two groups? How might this difference reflect varying levels of customer engagement, intent, or perceived value in a mental wellness app like Headspace?
#   </span>
# </div>

# %% [markdown]
# Using ChatGPT's response, write 2–3 sentences summarizing what you learned or what you think is the most likely explanation.

# %% [markdown]
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 3: Customer Acquisition
#
# We'll turn now to the `all_members` dictionary. `all_members` is a *new* dictionary that stores the data much differently. Each **key** is a unique user ID for all members (free and premium!) at Headspace. Its values are another dictionary 🤯 containing various attributes of each member.
#
# Each *value* in the `all_members` dictionary is itself a dictionary whose keys and values are...
# - `account_plan` : either "free" or "premium"
# - `registration_date` : the date the user registered for Headspace
# - `acquisition_type` : either "Organic" or "Paid", this is the market channel through which the user was acquired
# and a few more important attributes.
#
#
# Let's quickly familiarize ourselves with this data structure before we move onto the tackling the Customer Acquisition challenge.
#
# Look at user_id `10300491` and user_id `19078016` in the `all_members` dictionary.
#
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
#     <strong>Hint: </strong>These user_ids are <i>integers</i>, not strings!
# </span>
# </div>

# %%
# user_id 10300491

# %%
# Which marketing channel (organic or paid) did user_id 19078016 originate from?

# %% [markdown]
# Here's a new scenario: The marketing team want to compare and evaluate the conversion rates of organic acquisitions and paid acquisitions to determine which group is more likely to become paid Headspace subscribers.
#
#  Remember:
#  - **Paid acquisition** generates traffic to Headspace via paid ads. Think: social media ads, Google ads, TV commercials, etc.
#  - **Organic acquisition** generates traffic to Headspace over time for free. Think: blogging, social media, emails, referrals, etc.
#
# You'll complete this task together with your Team. If you get stuck, use the raise hand feature in Zoom and your Team Lead or LiveLab Instructor will be right in!
#
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
#     <strong>Hint: </strong>The <b>organic acquisition conversion rate</b> = number of premium users who came from an organic marketing channel divided by the total number of users who came from an organic marketing channel.
# </span>
# </div>

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> I'm trying to understand how to structure Python code that loops through an iterable and keeps track of how many times a specific item appears. Can you give me a simple example that counts how many times "apple" shows up in a list? I’ll be using this as a foundation for a more complex example later, so I want to make sure I understand the loop and counter structure clearly.
#   </span>
# </div>

# %%
# Initialize counters for number of PREMIUM users who came from an ORGANIC marketing channel
# and total number of users who came from an ORGANIC marketing channel
organic_premium_users = 0
organic_total_users = 0

# Similarly, initialize counters for number of PREMIUM users who came from a PAID marketing channel
# and total number of users who came from a PAID marketing channel
paid_premium_users = 0
paid_total_users = 0

# Loop through each user_id in the all_members dictionary
for user_id in all_members:

    # Check if the user's acquisition type is 'Organic'
    # If so, increment the total count of organic users


        # Check if the user has a premium account
        # If so, increment the count of organic users with premium accounts


    # Check if the user's acquisition type is 'Paid'
    # If so, increment the total count of paid users


        # Check if the user has a premium account
        # If so, increment the count of paid users with premium accounts

# Calculate the organic acquisition conversion rate
organic_conversion_rate =

# Print the organic acquisition conversion rate


# Calculate the paid acquisition conversion rate
paid_conversion_rate =

# Print the paid acquisition conversion rate

# %% [markdown]
# What do you notice? Is there a higher percentage of premium subscribers who came from *organic marketing channels* or of premium subscribers who came from *paid marketing channels*? Is this surprising? Why or why not?

# %% [markdown]
# Double-click (or enter) to edit!

# %% [markdown]
# Based on your answer to the previous question, and your understanding of organic and paid acquisition conversion rates, what insights could these findings provide regarding the allocation of marketing resources and the overarching growth strategy for Headspace? Your Team will share a recommendation with the whole LiveLab when we come back!

# %% [markdown]
# Double-click (or enter) to edit!

# %% [markdown]
# ## LevelUp: Checking if a Key Exists in a Dictionary
#
# Not all dictionaries are created equal. There are situations where a key that exists in  dictionary does not exist in in another. Let's practice how to handle those situations.
#
# First, write a loop that goes through each index in `member_ids_to_check` and prints the corresponding dictionary from `all_members`.

# %%
member_ids_to_check = [5535000, 5329129]

# %%
# Write code here to print the corresponding dictionary from all_members

# %% [markdown]
# Notice that between the two dictionaries printed, there are several keys that are present in one but not the other.
#
# Now, run the cell of code below and observe the error that is being thrown.
#
# Add an `if` statement to the existing code that either:
# - checks that the `country` key exists
# - or checks that the member is a premium member. If the account_plan is premium, then country will be a key in the dictionary!
#
# If you complete the task sucessfully, then the code should run error free!

# %%
for member_id in member_ids_to_check:
    print(all_members[member_id]["country"])

# %% [markdown]
# ## LevelUp: Find the User
#
# Write a for loop to loop through the `all_members` list and find the `id` of the member who had a `'premium'` membership and is located in `'Austrailia'`. The user registered on `'11/22/19'` and their account membership ended on `'4/29/20'`.
#
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
#     <strong>Hint: </strong>Remember that not all dictionaries in the <code>all_members</code> have a <code>country</code> key. In your condition, you will also have to check that the <code>country</code> key is present like you did in Task #1.
# </span>
# </div>
#
# <br>
#
# If your code is correct, you should expect to member id to be `19701386`.

# %%
# Write your code here
