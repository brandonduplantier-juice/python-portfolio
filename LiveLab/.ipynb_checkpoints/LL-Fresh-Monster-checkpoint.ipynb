# %% [markdown]
# # LiveLab | Fresh Monster Market Insights
# ![](https://m.media-amazon.com/images/S/stores-image-uploads-na-prod/3/AmazonStores/ATVPDKIKX0DER/b67b47b7745e1c0053f5d1783ddf601c.w3000.h600._CR0%2C0%2C3000%2C600_SX1500_.jpg)

# %% [markdown]
# ## Load the Data
# The dataset we'll be analyzing is called `fresh-monster-amazon-activity-data.csv`. Just like all our datasets, it lives in the the folder named `datasets`.
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> To load this data and the library you'll need into your Notebook, edit and run the following cells!
#   </span>
# </div>

# %%
# Import pandas library

# %%
# Load the dataset
fresh_monster =

# Preview the data

# %% [markdown]
# ## Warm Up: Explore
#
# As a warm up, let's explore Fresh Monster's Amazon data by seeing how many rows and columns we have and what data comprises each column.
#
# We'll also see just how many "shower steamers" and "shower steamers for kids" products we have in the data.

# %%
# How many rows and columns are in the data?

# %%
# What kinds of data are in each column? Are there any missing values?

# %% [markdown]
# ## Task 1:  Analyzing Market Demand
#
# Analyzing market demand will help Fresh Monster understand the level of interest and potential sales volume for the product, informing decisions on production volume and market entry strategy. We'll calculate the **total number of clicks** for both niches for a baseline understanding of general interest in these products.
#
# We'll need to focus on both niches -- "shower steamers" and "shower steamers for kids" -- separately.
#
# **A.** Let's create two new dataframes: `shower_steamers` and `shower_steamers_for_kids`.
# - Filter the data to only products that in the "shower steamer" niche. Store the filtered data in a new DataFrame called `shower_steamers`.
# - Calculate the total number of shower steamer products and the sum total of the clicks across all shower steamer products.
# - Repeat for shower steamer for kids products.

# %%
# Filter the DataFrame to include only shower steamer products
shower_steamers =

# How many shower steamer products are there?


# Using the 'Niche Click Count' column, calculate the total number of clicks across all shower steamer products

# %%
# Filter the DataFrame to include only shower steamer products for kids
shower_steamers_for_kids =

# How many shower steamer products for kids are there?


# Using the 'Niche Click Count' column, calculate the total number of clicks across all shower steamer for kids products

# %% [markdown]
# **B.** That was a lot of repeated code! See if you can write a `for` loop, iterating through e.g. `['shower steamers','shower steamers for kids']`, to print out the sum total of the clicks across all products in their respective niches.

# %%
for niche in ['shower steamers', 'shower steamers for kids']:
    # Filter the DataFrame to include only rows matching the current product niche


    # Calculate the total number of clicks using the 'Niche Click Count' column


    # Print the total clicks along with the product niche

# %% [markdown]
# Summarize your observations. What conclusions can you draw about the demand for shower steamers for kids?
#
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> I found that "Shower Steamers" have a X products and a total of X clicks, while "Shower Steamers for Kids" have X products and X clicks. Based on this data, what insights or conclusions can we draw about consumer interest, market demand, or potential opportunities?
#
#   </span>
# </div>

# %% [markdown]
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 2: Understanding the Competition
#
# Fresh Monster wants to know who is already competing in a “shower steamers for kids” category. Let's look a click share -- this is the percentage of clicks a product receives in its given niche. A product with a large click share means that it receives a significant proportion of total clicks within its niche, suggesting high customer interest and potential market dominance.
#
# **A.** Sort the filtered data of products only in the shower steamers for kids niche by click share. Display the top three products with the largest click share.

# %%
# Sort shower steamer products for kids by 'Click Share' in descending order


# Display the top three products with the highest click share

# %% [markdown]
# **B.** For each of these three products with the highest click share, display the Product Name, the Average Selling Price, and the Average Customer Rating.

# %%
# Print the Product Name of the shower steamer for kids with the highest click share

# %% [markdown]
# **C.** What is the **total click share** for these top three products combined?

# %%
# Calculate the combined click share of the top three products


# Format and print the result

# %% [markdown]
# Summarize your observations.
#
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 3: Assessing Market Competitiveness & Identifying a Market Gap
#
# Understanding market competitiveness and identifying gaps informs effective product positioning and differentiation, maximizing success potential by meeting customer needs.
#
# You'll complete this task with your Team! Feeling stuck? That's okay! We’re here to learn by doing and to help each other build skills. Use the raise-hand feature 🖐 in your Breakout Room, and your Team Lead or Instructor will be right in to help you!

# %% [markdown]
# **A.** Write a `for` loop that iterates through the list `['shower steamers','shower steamers for kids']` and prints ...
# - the average number of sellers and vendors for both categories over the past 360 days
# - the average BSR. BSR stands for "Best Seller Rank". It is a relative ranking system used by Amazon to indicate how well a product is selling in its category
# - the total ratings
# - and the average customer ratings

# %%
for niche in ['shower steamers', 'shower steamers for kids']:
    # Filter the DataFrame to include only rows matching the current product niche


    # Calculate the average number of sellers and vendors


    # Calculate the average Best Sellers Rank (BSR)


    # Calculate the total number of customer ratings


    # Calculate the average customer rating


    # Print a summary of the findings for this product niche

# %% [markdown]
# Summarize your observations. What conclusions can you draw market competitiveness and a market gap for Fresh Monster?
#
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> i observed that "Shower Steamers" have an average of X sellers, an average BSR of X, and a total of X ratings. In contrast, "Shower Steamers for Kids" have an average of X sellers, a higher average BSR of X, and a total of X ratings. Based on this data, what insights can we draw about overall market saturation, demand trends, and potential whitespace opportunities that Fresh Monster could capitalize on?
#   </span>
# </div>

# %% [markdown]
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 4: A Recommendation for Fresh Monster
# Let’s get back to Irena's motivation for this analysis. Together with our Team, summarize and integrate your observations on market demand, a pricing strategy, market competitveness, and a potential gap in the market. What should Irena and the Fresh Monster team know about going to market with this potential new product?

# %% [markdown]
# (Double-click (or enter) to edit!)

# %% [markdown]
# # LevelUp

# %% [markdown]
# ## Task 1: Visualize Average BSR by Niche
#
# Use the `px.histogram` function to plot the *average* of the Average BSR for both "shower steamers" and "shower steamers for kids". These are the same numbers you calculated in Task 3! You can use your previous calculations when checking that your visualization is correct.
#
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
# <strong>Hint: </strong>You'll need to use the <code>histfunc=</code> parameter here!
# </span>
# </div>

# %%
# Plot the average of the average BSR by niche using the px.histogram function

# %% [markdown]
# ## Task 2: Analyzing Price Sensitivity in the Market
#
# Understanding how price impacts customer demand is crucial for setting competitive prices. We’ll analyze the relationship between Average Selling Price and Click Share in the “shower steamers for kids” niche to understand how pricing affects market dominance.
#
#
# Create a scatter plot with the `Average Selling Price (Past 360 days) (USD)` on the x-axis and `Click Share (Past 360 days)` on the y-axis for all the products. Use the `color=` parameter to distiguish between "shower steamers" products and "shower steamers for kids" products.

# %%
# Plot Average Selling Price v Click Share

# %% [markdown]
# What insights can you glean from the scatter plot? How do the sizes of the bubbles vary between the niches? What do you notice about the spread of products across the x-axis? Which niche seems to have more large bubbles? What could this tell us about how competitive each niche is?

# %% [markdown]
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 3: Investigating Top Performers Over Time
#
# To better understand what drives success, we need to investigate which products have consistently remained popular.
#
# Find the top 5 products by total ratings in the "shower steamers for kids" niche, and determine whether these products also rank highly in click share.
#
# What are the common features of these top-rated products? Summarize your findings, focusing on key characteristics that Fresh Monster could consider when developing their own product.

# %%
# Write your code here

# %% [markdown]
# ## Task 4: More Exploratory Data Analysis
# You have the freedom to explore this dataset more deeply and come up with your own insights! Use your creativity and analytical skills to find patterns, trends, or interesting relationships that may not have been uncovered in any previous tasks.
#
# And hey, guess what!? This is true for *all* datasets you might ever come across!

# %%
# Write your code here
