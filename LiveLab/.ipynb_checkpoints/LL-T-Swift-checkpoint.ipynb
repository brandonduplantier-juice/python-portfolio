# %% [markdown]
# # LiveLab | The Perfect Taylor Swift Song
#
# ![](https://media.giphy.com/media/elaVskTaObtXEiejn5/giphy-downsized.gif)
#
# Just like [Syl's Taylor Swift Song Selector](https://sylkaren.tumblr.com/taylor-song-selector), the Python *function* `recommend_song` will recommend the perfect Taylor Swift song for you to listen to, based on...
# - what's contributing your mood,
# - whether or not you want to listen to Old Taylor or New Taylor,
# - and whether or not you have a specific Taylor Swift lyric on your mind.
#
# Let's have some fun with this FUNction called `recommend_song`!
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> To import the function into your notebook, run the following cell!
#   </span>
# </div>

# %%
# load the data
import sys
sys.path.append('./files')

from taylor_swift import recommend_song

# %% [markdown]
# ## Task 1: Running the `recommend_song` Function
#
# The `recommend_song` function requires 3 parameters, which are variables! These are essentially just containers of information, and you get to decide what goes inside these containers by giving them values.
#
# **(A)** Think about what's contributing to your mood right now. Store any one of the following contributors in a variable called `mood_contributor`
# - 'Love Interest'
# - 'Ex-Partner'
# - 'Myself'
# - 'Friend(s)'
# - 'Family'
# - 'Ex-Friend'
# - 'Other'
#
# **(B)** Are you feeling more Old Taylor or New Taylor? Can you even come to the phone right now? Store either "old" or "new" in a variable called `taylor_preference`.
#
# **(C)** 🎵Look what you made me do🎵 Do you have a Taylor Swift lyric on your mind? If so, store it in a variable called `lyric`. If you don't, it's okay! Don't you worry your pretty little mind 🎵 But still create a variable called `lyric` and assign to it an empty string (really wish we could call it an [Invisible String](https://open.spotify.com/track/6VsvKPJ4xjVNKpI8VVZ3SV)).

# %%
# Store what's contributing to your mood in a variable called mood_contributor


# Store your preference for Old Taylor or New Taylor in a variable called taylor_preference


# Store a Taylor Swift lyric in a variable called lyric

# %%
# Run the recommend_song function (do not change this line)
# Note: This won't display anything yet — it just stores the result!

song_title, recommended_song = recommend_song(mood_contributor, taylor_preference, lyric)

# %% [markdown]
# ## Task 2: Formatting & Printing the Function Output
# Now stored in the variable `recommended_song` is a link to listen to the song on Spotify! But it needs to be printed with a message to the screen.
#
# **(A)** Print `recommended_song`.

# %%
# Print recommended_song

# %% [markdown]
# **(B)** 🎵We know it's never simple, never easy🎵 <br> Now use an f-string to write a sentence that mirrors the following sentence. You'll use the variables `mood_contributor`, `taylor_preference`, `song_title`, and `recommended_song`.
#
# ***Example:*** <br>
# Since {<span style="color:green">Ex-Friend</span>} is the main contributor to your mood right now, {<span style="color:green">It’s Nice to Have a Friend</span>} is the {<span style="color:green">new</span>} Taylor Swift song you absolutely NEED to hear right now. Here’s a link: {<span style="color:green">[https://open.spotify.com/track/1SmiQ65iSAbPto6gPFlBYm](https://open.spotify.com/track/1SmiQ65iSAbPto6gPFlBYm)</span>}.

# %%
# Format and print an output string

# %% [markdown]
# ## Task 3: Debugging
# Debugging errors in code can be challenging and frustrating! Accept and embrace that you're going to make mistakes, so, [so so it goes...](https://open.spotify.com/track/5PxFv9yJEg9dxvbZggykro)😉
#
# The following cell has a few bugs in it! See if you can fix the bugs so that the code runs error free.

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> Please review this code for errors and explain what needs to be fixed so it runs correctly. (Paste the code)
#   </span>
# </div>

# %%
# Store what's contributing to your mood in a variable called mood_contributor
mood_contibutor = 'Ex-Friend'

# Store your preference for Old Taylor or New Taylor in a variable called taylor_preference
taylor_prefrence = 'new'

# Store a Taylor Swift lyric in a variable called lyric
lyric = 'This is why we can't have nice things, darling"

# Run the recommend_song function (do not change this line)
# Note: This won't display anything yet — it just stores the result!
song_title, recommended_song = recommend_song(mood_contributor, taylor_preference, lyric)

# Format and print the output
print(f'Here's the perfect Taylor Swift you need to listen to: {recommended_song}

# %% [markdown]
# ## Analyzing Taylor Swift Songs
# Data analysis in Python really [Hits Different](https://open.spotify.com/track/3xYJScVfxByb61dYHTwiby)... Let's take a sneak peak together!

# %%
# Import pandas & plotly libraries


# Load datas


# Preview dataset

# %%
# Distribution of mood_contributor

# %%
# Plot distribution of mood_contributor
