# %% [markdown]
# # LiveLab | Skullcapz Studio Closed Beta Analysis
#
# Skullcapz Studios needs the help of data analysts (that's you!) to make sense of the data collected from The Lost Kingdoms closed beta.
#
# Their mission is to market The Lost Kingdoms better, to improve the design, and make it more welcoming and accessible.

# %% [markdown]
# ### The Data
# You'll be using data from Skullcapz Studios!
# - demographic data come in the form of three distinct lists:
#   - `ages`: a list containing values representing the ages of the players
#   - `genders`: a list containing values that indicate the gender of the players
#   - and `countries`: a list containing values that indicate the country of residence of the players
#
# - metrics data come in the form of three more lists:
#   - `hours_played`: a list containing numeric values that indicate the total number of hours each player has spent playing the game
#   - `characters`: a list indicating the different character roles chosen by the players.
#   - and `boss_1_difficulty_ratings`: a list containing numeric values indicating the difficulty ratings assigned by players for the first boss encounter in the game
#
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> To load the data into your notebook, run the following cell!
#   </span>
# </div>

# %%
# Load the data
import sys
sys.path.append('./files')

from skullcaps_data import *

# %% [markdown]
# Before we dive in, let's get familiar with how the data is stored.

# %%
# Print the list of ages

# Print the list of genders

# Print the list of countries

# %% [markdown]
# ## Task 1: Average Age
# Clean the list of ages (so that each value is numeric) and calculate the average age of the closed beta players.

# %% [markdown]
# #### Pseudocode
# Write out the steps you would take to clean a list of ages and calculate the average. Think about how to handle values that might be stored as strings, like "23" instead of 23. Consider the specific actions you would take on each item in the list. Keep your steps clear and simple, as if you're explaining them to someone new to coding.

# %% [markdown]
# (double-click to edit)
#
#
# 1. create an empty list to store the "cleaned" ages, call it clean_ages
#
# 2.

# %% [markdown]
# #### Python
# Your pseudocode can *(and should)* become the comments to your Python code! Copy each step of your psuedocode above as a comment ahead of your Python code below.

# %%
# write comments AND code here

# create an empty list to store the "cleaned" ages

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> The average age of players is X. What does this tell me about Skullcapz Studios' target audience? What kind of game design or marketing decisions could be based on this?
#   </span>
# </div>

# %% [markdown]
# ## Task 2: Gender Breakdown
# Calculate the percentage of each gender in the list of genders.

# %% [markdown]
# #### Pseudocode
# Next, write down each step you would follow to calculate the percentage of each gender in the list of genders.
#
# <div style="border: 3px solid #f8c43e; background-color: #fff3c1; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#       <strong>Remember:</strong> The percentage of a gender in a list is comparing the number of players belonging to that gender with the total number of individuals in the list. So consider first how you will count the number of players belonging to a gender.
#   </span>
# </div>

# %% [markdown]
# (double-click to edit)
#
# 1.

# %% [markdown]
# #### Python
# Again, your pseudocode can *(and should)* become the comments to your Python code! Copy each step of your psuedocode above as a comment ahead of your Python code below.

# %%
# write comments AND code here

# %% [markdown]
# Is there a gender that is accounting for an overwhelming proportion of closed beta players?

# %% [markdown]
# (Double-click (or enter!) to edit)

# %% [markdown]
# ## Task 3: Country Breakdown
#
# **Localization analysis** refers to the process of analyzing and understanding the geographical or regional variations of the players. Skullcapz Studios is interested in where their closed beta players are residing. Calculate the percentage of each country (Germany, Brazil, Russia, France, Italy) in the list of countries.

# %% [markdown]
# #### Pseudocode
#
# ⚠️ Careful! It appears that there are inconsistencies in capitalization of various countries. How can you be sure ‘Germany’ and ‘germany’ are both counted?
#
# **Note** The list of countries in the dataset should be:
# - germany
# - brazil
# - russia
# - france
# - italy
#
# (notice how these are all lowercase 🧐)

# %% [markdown]
# (double-click to edit)
#
# 1.

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> Here’s the pseudocode I’ve written. Can you help me check if I’m missing any steps or if it could be clearer?
#   </span>
# </div>

# %% [markdown]
# #### Python

# %%
# write comments AND code here

# %% [markdown]
# In what country do you recommend Skullcapz Studios implement localization efforts?

# %% [markdown]
# (Double-click (or enter!) to edit)

# %% [markdown]
# ## Task 4: Summarizing Hours Played
#
# Next calculate the minimum, the maximum, and the average number of hours played.

# %% [markdown]
# #### Pseudocode
#
# (double-click to edit)
#
# 1.

# %% [markdown]
# #### Python

# %%
# write comments AND code here!

# %% [markdown]
# ## Task 5: Character Popularity
#
# Similar to Tasks 2 and 3, compute the percentage of each of the 4 classes: wizard, archer, fighter, and cleric.

# %% [markdown]
# #### Pseudocode
#
# (double-click to edit)
#
# 1.

# %% [markdown]
# #### Python

# %%
# write comments AND code here!

# %% [markdown]
# ## Task 6: First Boss Level of Difficulty
#
# Finally, compute the average of the boss 1 difficulty rating.

# %% [markdown]
# #### Pseudocode
#
# (double-click to edit)
#
# 1.

# %% [markdown]
# #### Python

# %%
# write comments AND code here!

# %% [markdown]
# With the difficulty rating on a scale of 1 to 5, (where 1 means the first boss level is really easy and 5 meas it is really difficult), did the closed beta players find the first boss level easy or difficult?

# %% [markdown]
# (Double-click (or enter!) to edit)

# %% [markdown]
# ## LevelUp
#
# **Note** LevelUps might cover concepts from future SkillBuilders.  This next portion of the LevelUp in particular borrows a bit from SkillBuilder 3. You can always come back to these files to show off new skills!

# %% [markdown]
# Earlier, you were working with three separate lists, which meant that we had to rely on the *index* to keep things in sync. In other words, we had to assume that the values at the same index in each list represented the same player.
#
# While that works, it’s a bit harder to manage and understand. By switching to dictionaries, each item holds all its related properties together, making the relationships clearer and the data easier to work with overall.
#
# Task #1 and #2 will focus on combining the information from the three lists in to a list of dictionaries.

# %% [markdown]
# ### Task #1
#
# Write a for loop that combines the information from the three lists (`ages`, `genders`, and `countries`) into a single list called `player_info`. Each element you appened to the `player_info` list should be a dictionary. And each dictionary should contain information from the same index across all three original lists.
#
# When you print `player_info`, it should look something like:
#
# ```
# [
#     {'age': '30', 'gender': 'w', 'country': 'united states'},
#     {'age': 29, 'gender': 'm', 'country': 'Japan'},
#     {'age': 43, 'gender': 'nb', 'country': 'United States'}
#     ...
# ]
# ```

# %%
# Create the player_info list
player_info = []

# Loop through each index in the ages list (or the genders or the countries lists!)
for index in range(len(ages)):
  # write comments AND code here

# %% [markdown]
# ### Task #2
#
# Now that we have all the dictionaries in `player_info`, let's do some data cleaning by looping over `player_info` so that:
#
# - the ages are all INT types
# - the gender and countries are all lowercase.
# - add the index into each dictionary as the "id". We don't want an id of zero though, so please make sure the id starts at 1.
#
# The new printed output would look something like:
#
# ```
# [
#     {'id': 1, 'age': 30, 'gender': 'W', 'country': 'united states'},
#     {'id': 2, 'age': 29, 'gender': 'M', 'country': 'japan'}
#     ...
# ]
# ```

# %%
# Create the cleaned player info list
clean_player_info = []

# Loop through each player (index) in the player_info list
for index in range(len(player_info)):
  # write comments AND code here!
