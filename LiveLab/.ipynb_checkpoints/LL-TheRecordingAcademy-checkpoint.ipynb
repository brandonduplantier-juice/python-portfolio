# %% [markdown]
# # LiveLab | Engagement Analysis for The Recording Academy
#
# <img src="https://naras.a.bigcontent.io/v1/static/ra_ga_logo"
#      width="400"
#      height="" />
#
# The Recording Academy, famous for its Grammy Awards, has partnered with the Global Career Accelerator. They're looking to gain valuable insights into the **level of engagement** generated by their social media posts.
#
# The goal of this LiveLab is to evaluate the effectiveness of The Recording Academy's content and campaigns, and offer data-driven suggestions for refining their social media strategy during the time of the year when The Grammy Awards are not taking place.

# %% [markdown]
# ### The Data
# You'll be using data given to the Global Career Accelerator from The Recording Academy! The primary dataset is called `tra_social_posts.csv`. Columns relevant to our social media engagement analysis are:
# - `Date`: The date when the social media post was published.
# - `Post ID`: Unique identifier assigned to each individual post.
# - `Content Type`: Indicates the type of content shared, such as text, image, or video.
# - `Link`: URL associated with the social media post.
# - `Engagements`: Number of interactions with the post, including reactions, comments, and shares.
# - `Engagement Rate (per Impression)`: Ratio of engagements to the number of *impressions* received.
#
#
# Remember: to load this data and the libraries you'll need (pandas and plotly.express) into your Notebook, edit and run the following cells!

# %%
# import the pandas and plotly.express libraries

# %%
# load the data

# preview the data

# %% [markdown]
# ## Task 1: Total Social Media Engagements
# Of course The Recording Academy wants to rack up their followers. But, ultimately, the greatest measure of social media success isn’t just a big audience, it’s an engaged one. **Social media engagement** shows how much people interact with posted content, as opposed to just viewing it.
#
# Using the plotly.express library, visualize the total number of all social media engagements for each individual date in the dataset.

# %%
# plot engagements by date

# %% [markdown]
# ## Task 2: The Most Popular Post on Grammy Night
# Before we get to analyzing engagement when the Grammy Awards are not taking place, let's warm up with the data by answering the following question: what was the most popular post each year on the night The Grammy's was held?
#
# Look closely at the preview of the data from The Recording Academy. We can't (easily) identify Grammy's Nights, can we? We'll need to join data from another dataset! The dataset `grammys_awards_dates.csv` has three columns: `date`, `awards_week`, and `awards_night`. The values in `awards_week` and `awards_night` are binary, with 0 representing dates outside of awards weeks or nights, and 1 indicating dates within awards weeks or nights. <br><br>

# %% [markdown]
# #### **Part A.**
# Read in the dataset called `grammys_awards_dates.csv` and store it in a DataFrame called `awards_dates`. Preview the dataset.

# %%
# load grammys_awards_dates.csv
awards_dates =

# preview data

# %% [markdown]
# #### **Part B.**
# Merge (a.k.a. *join*) the `awards_dates` DataFrame with your original DataFrame.

# %%
# merge awards_dates with social


# preview the data

# %% [markdown]
# #### **Part C.**
# Write a `for` loop that ...
# - iterates through each year in the data (2017, 2018, 2019, 2020, 2021, and 2022),
# - filters the merged DataFrame to a given year and the Grammy's awards night,
# - sorts the social media posts by the most engagements,
# - and prints out a statement similar to the following: <br>*The most popular post on Grammy's Night 2022 was: https://twitter.com/RecordingAcad/status/1510777110851325955*

# %%
# create a list of the years in the dataset
years =

# iterate through the list of years
for year in years:
    # filter for the current year and Grammy's awards night


    # sort the posts by the most engagements


    # use an f-string to print the first row of the sorted DataFrame
    # HINT: you'll need to use .iloc here:

# %% [markdown]
# ## Task 3: Exploring Non-Awards Night Content
#
# Remember the goal of this LiveLab? The Recording Academy wants to understand the type of content that resonates the best with their audiences during the time of the year when the Grammy Awards are *not* taking place.
#
# To figure it out, you'll focus on two metrics: the total number of `Engagements` and the `Engagement Rate` using the data for posts outside of awards weeks. <br><br>
#
# #### **Part A.**
# Filter the dataset to only social media posts posted on weeks when the Grammy Awards were not happening. Using your filtered DataFrame and the plotly.express library, visualize the total number of all social media engagements by content type. Don't forget to add a title! <br>
# **HINT:** You'll use `px.histogram` here!

# %%
# filter to non-awards weeks


# plot engagements by content type

# %% [markdown]
# #### **Part B.**
# While the number of engagements gives an indication of the overall popularity of a post, it's the engagement rate that is the real currency of social media analytics. The engagement rate reveals the *percentage* of people who chose to engage with content after seeing it!
#
# Using your filtered DataFrame again, visualize the average engagement rate for each content type. Don't forget to add a title! <br>
# **HINT:** You'll use `px.histogram` here with the `histfunc=` parameter!

# %%
# plot engagement rate by content type

# %% [markdown]
# Now what can you say about the engagement rate by content type by looking at your visualization?
#
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## Task 4: Summarize
# What can you infer from the data about the engagement and engagement rates of different types of content during non-awards weeks? What recommendations can be made for future content creation to drive engagement? Discuss with your Team!
#
# (Double-click (or enter) to edit!)

# %% [markdown]
# ## LevelUp:
# You discovered in Task 3 that  video content is generating the highest number of engagements. Here, we'll calculate the *proportion* of each content type, so we can gain insights into the distribution of engagement across different types of content.
#
# Use the `.value_counts` method to count the occurrences of each unique value in the `Content Type`. In the same line of the code, divide by the total number of values in the `Content Type` column. This will return the proportion of each content type in the data.
#
# <span style='background-color: rgba(138, 43, 226, 0.4); padding: 0.2em 0.4em; border-radius: 4px;'>Note:</span> you can alternatively set the parameter `normalize=True` inside the `.value_counts()` method, which will automatically compute the proportions for you without having to perform any division!

# %%
# calculate the proportion of each content type used:

# %% [markdown]
# What can you say about engagement by content type by looking at your visualization and considering the proportions of each content type in the data? Does this change your recommendations in Task 4?
#
# (Double-click (or enter) to edit!)
