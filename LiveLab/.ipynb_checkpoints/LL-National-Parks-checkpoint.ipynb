# %% [markdown]
# # LiveLab | The National Park Service
#
# <div style="text-align: center;">
# <img src="https://upload.wikimedia.org/wikipedia/commons/1/1d/US-NationalParkService-Logo.svg"
#     width="175"/>
# </div>
#
#
#
# The National Park Service needs the help of data analysts (that's you!) to create inforgraphics for a new promotional campaign. Their focus is on the national parks found in our nation's capital, Washington D.C.
#
#
# This LiveLab will highlight the most recently published data, with a particular emphasis on the parks found in and around Washington D.C. By summarizing and exploring the data, you'll ensure the accuracy, validity, and meaningfulness of the data that gets used for the new campaign.

# %% [markdown]
# ## The Data
# You'll be using data directly from the [National Park Service](https://www.nps.gov/).
# - `national_parks_recreation_visits` is a csv file that contains each and every National Park located in the general Washington DC area in the year 2024 and the total total amount of visits across each park.
# - `monthly_dc_visitors.csv` is a csv file containing the total number of visits across all the National Parks in DC for each month in 2024! The file contains many kinds of visits, not just recreational visits.
#
# You'll need to load this data and the libraries you'll need into your Notebook!

# %%
# Import libraries
# - pandas
# - plotly.express

# %%
# Load the national_parks_recreation_visits data
total_visits_df =

# Preview

# %% [markdown]
# ## Task 1: Number of National Parks & Monuments
# How many National Parks are there in Washington DC? Use the print function and an f-string to print a sentence with the number of national parks in the DC area.

# %%
# Calculate the number of Parks in DC

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> In pandas, what’s the difference between <code>df.shape[0]</code>, <code>df['column_name'].count()</code>, and <code>len(df)</code>? What does each one return, and in what situations might they produce different results?
#
#   </span>
# </div>

# %% [markdown]
# ## Task 2: Total Visits
#
# How many total visits were there at all the parks in Washington DC? Use the print function and an f-string again to print the total visits to the screen.
#
#
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
# <strong>Hint: </strong>You'll need to use the <code>.sum()</code> method here!
# </span>
# </div>

# %%
# Calculate total visits

# %% [markdown]
# ## Task 3: Popular Parks
# What are the most popular parks in the DC area?
#
# Using `ParkName` and `RecreationVisits` in your DataFrame, create a visualization to display the total number of visits to each park.

# %%
# Create visualization

# %% [markdown]
# What are the two most popular National Parks in the DC area?

# %% [markdown]
# (Double-click to edit!)

# %% [markdown]
# ## Task 4: Popular Seasons
#
# First you'll need to load the `monthly_dc_visitors.csv` into a DataFrame named `visits_df`. Preview the DataFrame.

# %%
# Load dataset

# Preview data

# %% [markdown]
# Use the `Month` and `RecreationVisits` columns in the dataframe to create a visualization displaying the total number of recreation visits each month.

# %%
# Create a line chart of total visits by month

# %% [markdown]
# Which months (or *season*) is the most popular for park visits in the Washington DC area?

# %% [markdown]
# (Double-click to edit!)

# %% [markdown]
# # LevelUp!

# %% [markdown]
# ## Task 1: Add a new column
#
# In our previous visualizations, the Month was displayed as a number (e.g., 1 for January, 2 for February, etc.).  Let's enhance the clarity and readability by adding a column called `Month verbose` to the `visits_df` dataframe that will contain the full month names instead of just numbers.
#
# Your task is to write a **function** called `month_verbose` that takes in a numerical value representing a month (from 1 to 12) and returns the corresponding month name as a string.
#
# Once you've defined the function, we will apply it to our dataframe to create the new column. Display both the `Month` and the new `Month verbose` columns so you can spot check your work.

# %% [markdown]
# <div style="border: 3px solid #30EE99; background-color: #f0fff4; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
#   <span style="font-size: 10pt;">
#     <strong>Try This AI Prompt:</strong> I have a pandas DataFrame with a <code>Month</code> column (1–12). Help me write a function called <code>month_verbose</code> that maps numbers to month names, then apply it to create a new column called <code>Month verbose</code>.
#
#   </span>
# </div>

# %%
# Define the function that takes in a number representing a month
def month_verbose(val):



# Use the function to create a new column in the visits_df dataframe
# Note: this is part of SkillBuilder 8!
visits_df['Month verbose'] = visits_df['Month'].apply(month_verbose)

# Preview your DataFrame

# %% [markdown]
# ## Task 2: Compare Recreation Visits with NonRecreation Visits Using a Line Graph
#
# Using the `visits_df` DataFrame create a line chart that shows RecreationVisits vs NonRecreation visits by month.
#
# **Note**: Use the new `Month verbose` column, but be sure to update the label so the x axis label does not say `Month verbose`)

# %%
# Write your code here

# %% [markdown]
# Describe how the Recreation Visits trend compares to the NonRecreation Visits. Why do you think that is?

# %% [markdown]
# (Double-click to edit!)

# %% [markdown]
# ## Task 3: Compare Hours by Type Using a Stacked Bar Chart
#
# Let’s compare how time is spent in parks month to month. Create a **stacked bar chart** that shows the number of **RecreationHours** and **NonRecreationHours** for each month.
#
# 🎨 Customize the bars so each category is represented by a specific color:
# - `RecreationHours`: `palevioletred`
# - `NonRecreationHours`: `darkmagenta`

# %%
# Write your code here
