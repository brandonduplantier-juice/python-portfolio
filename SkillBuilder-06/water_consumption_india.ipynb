# %% [markdown]
# # Water Consumption in India

# %%
# import libraries

# %% [markdown]
# ## Visualization #1
# Using the `water_extraction.csv` data, create a chart that displays the ten countries with the highest amount of groundwater extraction.

# %%
# load data

# %%
# create your first visualization.

# %% [markdown]
# ## Visualization #2
# Using `avg_rainfall_by_district.csv`, create a chart that displays the average rainfall by district in India.

# %%
# load data

# %%
# create your second visualization
