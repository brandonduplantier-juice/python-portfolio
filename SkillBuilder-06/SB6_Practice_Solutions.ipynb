# %% [markdown]
# # Practice!
#
# ![](https://media.giphy.com/media/11RzDlgr9U8wM0/giphy.gif)

# %%
# import pandas and plotly express libraries
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Effort 1 - Inspect your data!
#
# In this practice assignment, you will work with a dataset of the top 1,000 streamers on the Twitch platform.

# %% [markdown]
# Load `twitch.csv` into a pandas DataFrame and preview the first five rows. Recall that the `twitch.csv` is in the `datasets` folder.

# %%
# Load the dataset into pandas and preview it
df = pd.read_csv('datasets/twitch.csv')

# %% [markdown]
# Preview the last seven rows of the DataFrame

# %%
# preview last 7 rows of data
df.tail(7)
# Out:
#                Channel  Watch time(Minutes)  Stream time(minutes)  \
# 993  LAGTVMaximusBlack            123125340                161535
# 994        Destructoid            122628630                103020
# 995          LITkillah            122524635                 13560
# 996   빅헤드 (bighead033)            122523705                153000
# 997     마스카 (newmasca)            122452320                217410
# 998      AndyMilonakis            122311065                104745
# 999               Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 993          7138              725     256353             13251       2310313
# 994         14566             1190      48007              8995      87603521
# 995         21359             9104     601927            562691       2162107
# 996          3940              793     213212             52289       4399897
# ...

# %% [markdown]
# View twenty randomly chosen rows of the DataFrame

# %%
# sample 20 random rows
df.sample(20)
# Out:
#                 Channel  Watch time(Minutes)  Stream time(minutes)  \
# 890          Japan_ASMR            138935670                509670
# 518              Mibrtv            228640020                 82620
# 889             JonBams            139067415                 88830
# 33               DrLupo           1517612010                172350
# 322        오킹 (obm1025)            346276365                 96000
# 638        SovietWomble            187497450                 63360
# 839              Tourva            146412075                116070
# 924           CouRageJD            131341275                 14010
# 932           StarCraft            130159470                 14850
# 507        룩삼 (looksam)            232224165                 75030
# 994         Destructoid            122628630                103020
# 324            BlackUFA            345166455                 88035
# 842      PainLivestream            145610160                 89775
# ...

# %% [markdown]
# View the index of the DataFrame

# %%
# View the index
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# View the column names

# %%
# View the column names
df.columns
# Out:
# Index(['Channel', 'Watch time(Minutes)', 'Stream time(minutes)',
#        'Peak viewers', 'Average viewers', 'Followers', 'Followers gained',
#        'Views gained', 'Partnered', 'Mature', 'Language'],
#       dtype='object')

# %% [markdown]
# ### Effort 2 - Gather facts about your data!
#
# View information about the DataFrame, including its index, number of rows without missing data, and data type of each column

# %%
# View basic information about the DataFrame, including data types,
# index, column names, and number of rows without missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Channel               1000 non-null   object
#  1   Watch time(Minutes)   1000 non-null   int64
#  2   Stream time(minutes)  1000 non-null   int64
#  3   Peak viewers          1000 non-null   int64
#  4   Average viewers       1000 non-null   int64
#  5   Followers             1000 non-null   int64
#  6   Followers gained      1000 non-null   int64
#  7   Views gained          1000 non-null   int64
#  8   Partnered             1000 non-null   bool
#  9   Mature                1000 non-null   bool
#  10  Language              1000 non-null   object
# dtypes: bool(2), int64(7), object(2)
# memory usage: 72.4+ KB

# %% [markdown]
# View the statistical summaries of each numerical column, including the mean, median (50th percentile), min and max values, and the standard deviation. Use the `.describe()` method.

# %%
# View statistical summaries by column
df.describe()
# Out:
#        Watch time(Minutes)  Stream time(minutes)   Peak viewers  \
# count         1.000000e+03           1000.000000    1000.000000
# mean          4.184279e+08         120515.160000   37065.051000
# std           5.496355e+08          85376.201364   60314.307686
# min           1.221928e+08           3465.000000     496.000000
# 25%           1.631899e+08          73758.750000    9113.750000
# 50%           2.349908e+08         108240.000000   16676.000000
# 75%           4.337399e+08         141843.750000   37569.750000
# max           6.196162e+09         521445.000000  639375.000000
#
#        Average viewers     Followers  Followers gained  Views gained
# count      1000.000000  1.000000e+03      1.000000e+03  1.000000e+03
# mean       4781.040000  5.700541e+05      2.055185e+05  1.166817e+07
# std        8453.684965  8.044134e+05      3.399137e+05  2.490572e+07
# min         235.000000  3.660000e+03     -1.577200e+04  1.757880e+05
# ...

# %% [markdown]
# ### Effort 3 - Visualize your data!
#
# Use `px.histogram()` to create a bar chart of the average number of followers by streaming language. Use `histfunc='avg'` to aggregate the data. Which languages have the highest number of followers on average?

# %%
# Bar chart of the average number of followers by streaming language
px.histogram(df, x='Language', y='')

# %% [markdown]
# ## Level Up

# %% [markdown]
# Create a scatter plot of the number of followers and the total stream time. Total stream time should be on the x-axis, and the number of followers should be on the y-axis. Does higher stream time correlate with an increase in the number of followers?

# %%
# Scatter plot of number of followers and total stream time.
