# %% [markdown]
# # Plotly Express Line Charts
#
# You will be working with weather data from 2015-2020 recorded in Atlanta, Georgia. Precipitation is given in terms of inches, while temperatures are given in terms of Fahrenheit. You'll find the data in `atl_weather.csv` located in the `datasets` folder.

# %%
# import libraries

# %%
# import data

# preview

# %%
# Plot the average monthly highs in Atlanta

# %%
# Plot the average precipiation in Atlanta

# %% [markdown]
# ###  Multi-Line Charts
#
# Next you'll need precipiation data for both Atlanta, Georgia and Dallas, Texas found in `atl_dfw_weather.csv` located in the `datasets` folder.

# %%
# load data 

# preview

# %%
# Plot the average precipiation in Atlanta and Dallas
