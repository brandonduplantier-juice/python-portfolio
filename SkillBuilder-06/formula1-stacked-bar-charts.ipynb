# %% [markdown]
# # Formula 1 Constructors

# %% [markdown]
# `formula1_constructors_points` is a dataset containing information about Formula 1 constructors’ – AKA teams’ – standings at the end of each season, from 2010 to 2022.

# %%
# import libraries 

# load our data 

# preview our data

# %% [markdown]
# ### Visualizing Points Per Constructor
# Use `plotly.express` to visualize the trends in points per team, by season
