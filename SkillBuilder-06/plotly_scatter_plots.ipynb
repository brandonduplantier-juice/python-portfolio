# %% [markdown]
# ### Scatter Plots

# %%
# import our libraries
import pandas as pd
import plotly.express as px

# read the data
games_df = pd.read_csv('datasets/nba_games_2018.csv')

# %%
# scatter plots depict one numeric feature against a second one

# %%
# use color to differentiate between groups

# %%
# use color to differentiate between groups
