# %% [markdown]
# # Plotly Express Bar Charts
#
# You will be working with weather data from 2010-2019 recorded from eleven selected cities in the contiguous United States. Precipitation is given in terms of inches, while temperatures are given in terms of Fahrenheit.

# %% [markdown]
# You'll be working with some weather data from 2010 to 2019 stored in `us_weather_summary.csv` located in the `datasets` folder. This includes the average percipation and the average maximum daily temperatures for various US cities.

# %%
# import libraries

# %%
# load data

# preview

# %% [markdown]
# ## Bar Charts

# %%
# Plot the average daily precipitation by city

# %%
# Plot the average high daily temperature by city

# %% [markdown]
# ## The `px.histogram` Function
#
# Let's have a look at the *raw* data in `us_weather.csv` and see what's different with how we interact with Plotly. This new dataset includes only the maximum temperature for each city, but for several days now between 2010 and 2019.

# %%
# load data

# preview

# %%
# Using px.bar for the high temperatures by city

# %%
# Using px.histogram for the high temperatures by city

# %% [markdown]
# ### Histograms
# A histogram shows the *shape* of the data

# %%
# A histogram of high temperatures

# %% [markdown]
# ## LevelUp: Labels & Titles

# %%
# Add axis labels and title to a chart

# %%
# A horizonal bar chart
