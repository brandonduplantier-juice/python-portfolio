# %% [markdown]
# # A Safer Barcelona

# %% [markdown]
# Set up your notebook:
# * Import the `Pandas` and `Plotly.express` libraries
# * Use the `pd.read_csv` function to load `barcelona_accidents.csv` data file as a dataframe

# %% [markdown]
# ## Visualization #1:
# Using the `barcelona_accidents.csv` data create a visualization to display the number of accidents, by day of the week.

# %% [markdown]
# ## Visualization #2:
# First, load a second data file named `accidents_by_date.csv`.
# Then, create your second visualization illustrating the number of accidents each day of the year by district.

# %% [markdown]
# Can you add a title to that last line plot highlighting car accidents in Eixample and Ciutat Villa?

# %% [markdown]
# ### LevelUp:
# Impressed with your first two visualizations, the Mayor is hoping you might be willing to create a third. The Mayor would like to see a bar chart illustrating the total number of accidents that occur each day of the week *and* each part of the day. For example, your bar chart should show the number of accidents that occurred on Monday in the morning, the afternoon, and at night. **HINT:** You should use the `barmode=` functionality within `px.histogram`
