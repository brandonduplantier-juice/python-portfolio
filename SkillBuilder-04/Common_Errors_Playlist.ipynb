# %% [markdown]
# ### Common Errors with loops and functions
#
# * Missing a colon when defining a function or loop
# * variable not defined
# * Infinite Loop

# %%
def create_playlist()
    
    # prepare to loop until the playlist is complete
    playlist_done = False
    
    playlist = []
    
    while not playlist_done
        title = input('What is the name of the song you want to add? ')
        artist = input('What is the name of the artist of that track? ')
        
        playlist.append({'title': title, 'artist': artist})
        print(f'{title} by {artist} has been added to the playlist.')
        
        print(f'Would you like to add another track to the playlist?')
        continue_response = input('Type "Yes" or "Y" to add another track. ')
        
    
    # once the loop is over, return the completed playlist
    return playlist

# %%
create_playlist()
