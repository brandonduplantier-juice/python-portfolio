# %% [markdown]
# # Practice your skills!
#
# ![](https://media.giphy.com/media/LBsqN9KIwOrIx1CJ08/giphy.gif)

# %% [markdown]
# ### Effort 1 - That's so `random`!
#
# The ability to call upon random pieces of data or generate random options for users to interact with are essential tools for a coder to have. If you have ever played any modern video game, there is a very strong likelihood that some of the data (level layout, points, damage, etc) were generated randomly!
#
#
# In the code below, we are going to generate a random choice of a user playing a game of rock, paper, scissors. You're only going to code the random part, but in the **LevelUp** section at the end of this notebook, you will have the opportunity to code the entire game up yourself!
#
# Begin by importing the `random` library and use the `random.choice` function to generate a random option from the list provided below.

# %%
# run this cell
import random

# Rock, paper, scissors options
rpg_choice = ["rock", "paper", "scissors"]

# select a random choice from the rpg_choice list

# %% [markdown]
# ### Effort 2 - Functions!
#
# ![](https://media.giphy.com/media/guaw7aMoRt56xxl30f/giphy.gif)
#
# Functions are like wizard spells for coders. Once learned, they can be called upon at any time to make your code more powerful and more efficient.
#
# We will write several functions below, increasing the difficulty each time, to highlight their usefulness.
#
#
# **a.** Write a function called `multiply`.
#
# - It should take two arguments, called `num1` and `num2`.
# - The function should simply multiply the two numbers and `return` the result.
#
# Test it by calling (running) the function to multiply 45 by 55. The result should be 2475.

# %%
# define function here
def multiply(num1, num2):
    # multiply the numbers

    # output the result

# %%
# This should return 2475
multiply(45, 55)

# %% [markdown]
# ![](https://media.giphy.com/media/dUxYz6EpKOVsntW8ZT/giphy.gif)
#
# **b.** Now write a function called `convert_celsius`, which will convert Celsius temperatures to Fahrenheit.
#
# - It should take one argument, called `temp_C`.
# - The function should `return` the Fahrenheit equivalent by using the equation `temp_F = temp_C * 5/9 + 32`.
#
# Test your function by running the cells below.

# %%
# define function here

# %%
# result should be 32 (or 32.0)
convert_celsius(0)

# %%
# result should be 95 (or 95.0)
convert_celsius(35)

# %% [markdown]
# **c.** Now write a function called `convert_fahrenheit`, which will convert Fahrenheit temperatures to Celsius.
#
# - It should take one argument, called `temp_F`.
# - The function should `return` the Celsius equivalent by
# using the formula `temp_C = (temp_F - 32) * 5/9`.
#
# Test your function by running the cells below.

# %%
# define function here

# %%
# This should return 0 (or 0.0)
convert_fahrenheit(32)

# %%
# This should return 35 (or 35.0)
convert_fahrenheit(95)

# %% [markdown]
# ![](https://media.giphy.com/media/3o6nV5vcdVJw1RyT6g/giphy.gif)
#
# **d.** Finish writing the function below, called `convert_temp`.
#
# ***Side note*** - This function is the equivalent of toggling between Celsius and Fahrenheit on your weather app! This is similar to how Apple would have coded it!

# %% [markdown]
# This function asks the user the enter the temperature to convert. It then asks the user whether to convert the temperature to Celsius or Fahrenheit.
#
# Notice that after each instance of asking the user's input, the response is converted from string to number with the `float()` and `int()` functions. (This is because by default anything captured with `input` is treated as a `string`)
#
# The finished function should convert the entered temperature to Celsius or to Fahrenheit, depending on the user's selection. You can call (run) the `convert_fahrenheit` and `convert_celsius` functions you wrote above in this exercise, in this manner:
#
# ```python
# # check if temp_scale is celsius
# if (condition to check):
#     return convert_celsius(temp)
# ```

# %%
def convert_temp():

    # do not modify this section
    temp = input("Please enter the temperature you would like to convert.\n")
    temp = float(temp)

    temp_scale = input("Type 1 to convert C to F. Type 2 to convert F to C.\n")
    temp_scale = int(temp_scale)

    # write code below to finish function
    # check if temp_scale is celsius

        # convert celsius to fahrenheit


    # else convert fahrenheit to celsius

# %%
# run this cell to test your function!
convert_temp()

# %% [markdown]
# ## Level Up

# %% [markdown]
# ![](https://media.giphy.com/media/ir3tx5u0lQ5dEhKmz8/giphy.gif)
#
# Let's create a fully functioning game of Rock, Paper, Scissors. In this version of the game it will be a human user playing against a computer. Before you tackle such a big task, it's best to always outline the steps you need your code to execute.
#
# <br><br>
# **Outline of RPS Game:**
#
# 1. Grab `input` from human player
#     - Check that input is valid (provided for you)
# 2. Choose a `random` option for the computer player
# 3. Check who won (computer or human player)
# 4. Ask human player if they want to play again
#     - if so, go back to item 1
#     - otherwise, exit game
#
# <br><br>
# Earlier in this notebook you used the `random` library to select a random selection from a list of options. We will reuse that code again for the second bullet point (part of your work is already done!)

# %%
# get response from human
# complete function
def human_choice():
    # ask them to select (r)ock, (p)aper, or (s)cissors
    # to simplify for the user, only the first letter is needed
    user_choice =

    # return lower case
    return user_choice.lower()

# %%
# function to validate option from human player
# DO NOT MODIFY - RUN THE CELL ONLY
def validate_response(user_choice):
    if user_choice.lower() in ['r', 'p', 's']:
        return True
    else:
        return False

# %% [markdown]
# Okay, great job! Now to generate the response from the computer.
#
# **hint:** You already did this earlier in the notebook!

# %%
# Rock, paper, scissors options
# switching to letter only for simpler reading

# complete function
def random_choice():
    rpg_choice = ["r", "p", "s"]

    # randomly select option for computer
    computer_choice =

    return computer_choice

# %% [markdown]
# Let's review your checklist!
#
# 1. ~Grab `input` from human player~
#     - ~Check that input is valid (provided for you)~
# 2. ~Choose a `random` option for the computer player~
# 3. Check who won (computer or human player)
# 4. Ask human player if they want to play again
#     - if so, go back to item 1
#     - otherwise, exit game
#
#
# <br><br><br>
# Great progress! Now onto a tricky one. Determining who won the game!
#
# Recall the rules of the game:
#
# * `paper` wins over `rock`
# * `rock` wins over `scissors`
# * `scissors` wins over `paper`
# * if both users select the same option they tie the game
#
# <br><br>
#
# These rules are easy to remember, but can be tricky to code.
#
# The first (easiest) thing you want to check is if the human and computer have the same value. If they do, *print a message that the game ended in a tie.*
#
# Then, go check if `user_choice` is the option on the left of the list above and check if the `computer_choice` is equal to the one on the right. In other words, you only need to check these 3 options for the user (`'p'`,`'r'`,`'s'`) and check if the computer has the options (`'r'`,`'s'`,`'p'`), respectively.
#
# In all other case, the computer wins!
#
# ```python
# # you must first check `if` the game is a tie then
# # use template to check if user wins against computer
# elif user_choice == 'p' and computer_choice == 'r':
#     print('You win!')
#
# elif ...
#     print('You win!')
#
# elif ...
#     print('You win!')
#
# else:
#     print('You lose!')
#
# ```

# %%
def determine_winner(user_choice, computer_choice):
    # print options to screen
    print(f'You selected {user_choice}.')
    print(f'Computer selected {computer_choice}.')

    # check for tie


    # follow template above to determine winner

# %% [markdown]
# Now on to the last part of our code!
#
# <span style='background-color: rgba(138, 43, 226, 0.4); padding: 0.2em 0.4em; border-radius: 4px;'>*To make this game play you need to know: How many times does the human player want to play the game?*</span>
#
# You don't know! Which means you will have to use a `while` loop and exit that loop once the user decides to stop playing. The template below should be your starting point. Everything else will go *inside* the `while` loop.
#
# ```python
# # set flag for loop
# continue_playing = True
#
# while continue_playing:
#     # play RPS!
# ```

# %%
def play_game():

    # set flag for loop
    continue_playing = True

    while continue_playing:
        # Play the game!

        # DO NOT MODIFY THIS SECTION
        user_choice = human_choice()
        computer_choice = random_choice()

        while not validate_response(user_choice):
            user_choice = human_choice()

        determine_winner(user_choice, computer_choice)

        # COMPLETE THE CODE BELOW
        # ask the user if they want to continue playing (y/n)
        play_again =

        # check if play_again is not equal 'y'. convert to lowercase for simplicity

            # if so, change continue_playing to False
            # and print "thank you for playing!"

# %%
# play the game!!!!! Show off those skills!
play_game()
