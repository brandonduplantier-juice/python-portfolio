# %% [markdown]
# ## Advanced Python Techniques
#
# Now that you have a firm grasp of the Python fundamentals, in this notebook you will learn about two concepts that will make you a better problem solver.
#
# * Zipped Lists
# * Nested `for` loops
#
# ### Zipped Lists
# Zipping lists allows you to combine multiple lists together to simplify looping through the lists or dictionaries.

# %%
first_names = ['Hannah', 'Patricia', 'Caleb', 'Philippe', 'Theodore', 'Francisca', 'Justin', 
               'Lauren', 'Juliana', 'Joséphine']
last_names = ['Pergande', 'Castro', 'Mitchell', 'Peltier', 'Lata', 'Granados', 'Kruschwitz', 
              'Contreras', 'Murillo', 'Abbott']

# %%
# check that both lists have the same size

# %%
# iterate through both lists the "old" way

# %%
# Iterate through both lists using the "new hotness"

# %%
# Let's add a third list to our zip function
middle_names = ['Jennifer', 'Maria', '', 'Bertrand', 'Aldo', 'Leticia', 'Kevin',
                'Elizabeth', 'Daniela', '']

# %%
# Iterate through 3 lists!

# %%
# What happens if the lists are of different lengths?

# add your last name to the last_names list


# Zip again!

# %% [markdown]
# ## Nested For Loops
# As you may have guessed, a nested `for` loop is when you have a `for` loop
# inside of a different `for` loop.
#
# Let's look at how they work.

# %%
# Robert's clothing options

pant_colors  = ['Blue', 'Black', 'Gray', 'Burgundy']
shirt_colors = ['Orange', 'White', 'Green', 'Coral', 'Pink']

# %%
# Print out every possible combination of items Robert can wear

# Outer loop

    # Inner loop

# %%
# reverse it!
