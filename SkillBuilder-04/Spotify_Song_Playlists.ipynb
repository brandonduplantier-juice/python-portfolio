# %% [markdown]
# ## Coding Problem
#
# You will be building a series of functions in Python that emulates the creation and play of song playlists, similar to what can be done on music platforms like Spotify. These functions serve the essential features of playlist creation and use:
# - `create_playlist` builds a playlist by receiving input from the user.
# - `play_playlist` prints out a created playlist, one song at a time.

# %% [markdown]
# ### Task 1: Creating a Playlist
#
# The `create_playlist()` function will take user inputs to return a song playlist, formatted as a list with each element being one song. Each song, in turn, is recorded as a dictionary of song features, including the track title and artist. For example, this could be one potential playlist created:
#
# ```
# [{'title': 'Happy', 'artist': 'Pharrell Williams'},
#  {'title': 'Mr. Blue Sky', 'artist': 'Electric Light Orchestra'},
#  {'title': 'Good Day Sunshine', 'artist': 'The Beatles'}]
# ```
#
# User inputs should be in two parts:
# - First, the user should provide the title and artist for a track that will be added to the playlist.
# - Second, the user should be prompted if they want to add another track to the playlist. If they respond "Yes", then return to the first step to add another track. Otherwise, complete the playlist and return it to the user.

# %%
def create_playlist():
    # set up a list to contain our created playlist

    
    # prepare to loop until the playlist is complete
    
        # take input from the user to add a new track to the list
        
        # add the track as a dictionary to the end of the playlist
        
        # prompt the user whether or not they would like to add another song
    
    # once the loop is over, return the completed playlist

# %% [markdown]
# ### Task 2: Playing a Playlist
#
# The `play_playlist()` function should take one argument: a playlist previously created from the `create_playlist()` function. The function should print the song title and artist for each track, in order. For example, your output might look like this:
#
# ```
# Now playing Happy by Pharrell Williams
# Now playing Mr. Blue Sky by Electric Light Orchestra
# Now playing Good Day Sunshine by The Beatles
# ```

# %%
# Test out the structure of the data

# %%
def play_playlist(playlist):
    
    # loop over the playlist and...
    
        # print a message with each track's song and artist
