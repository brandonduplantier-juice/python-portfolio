# %% [markdown]
# # How to Import a Library

# %% [markdown]
# Below is a list of usernames who entered to win a sweepstakes. Use the `random.choice` function from Python's `random` library to select a sweepstakes winner at random.

# %%
usernames = ['demesne', 'freewheeling', 'bonanza', 'bungalow', 'wishywashy',
'cattywampus21', 'chrystocrene', 'baragnosis', 'quietus', 'behoove', 'zoocytium',
'snickersnee', 'hoosegow', 'blobcody', 'bigmouth55', 'staccato', 'epiphany',
'toftrought', 'jadeben2703', 'grudgemental', 'borborygm', 'sergenton180', 
'kerplunk', 'brevity', 'pannikin', 'peckted_rb25', 'meetdsm95', 'cattywampus',
'prowormquokka', 'jujubes', 'yatobo2', 'afganpongee', 'flumenrajxx',
'ruffian', 'lintelmhn23', 'obihead1314', 'jabberwocky', 'willynilly',
'squeegee', 'squooshy', 'sleepwups444', 'stetkerbl01', 'bogey', 'pupperhaus',
'stapediform', 'vauntiness','schmaltzy']
