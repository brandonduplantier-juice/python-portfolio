# %% [markdown]
# # User Defined Functions
#
# Your local coffee shop, Cups Community Coffee, offers a loyalty punch card system: each coffee purchase earns a customer a punch. After four punches, their next coffee is free.
#
# Practice writing a function accepts
# * the number of coffees a customer would like to purchase
# * the number of punches they have
# and prints the total cost of the coffee order. One coffee at Cups costs $3.15.

# %% [markdown]
# ### The Function Body
# Calculate the total cost for one particular customer's order:
# * Coffees to purchase: 2
# * Number of punches: 3

# %%
# initialize variables for customer data

# initialize and track the total cost of the order 

# Loop over number of coffees in order

# print to screen

# %% [markdown]
# ### The Final Function

# %% [markdown]
# Call the function, just like you would any other function!

# %% [markdown]
# ### A return statement
#
# Edit our function so that it returns the total cost of the order.
