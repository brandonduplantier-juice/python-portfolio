# %% [markdown]
# # While Loops

# %% [markdown]
# Netflix's "Are you still watching? (y/n)" prompt appears:
# * after watching 3 episodes of a TV show in a row,
# * or after 90 minutes of uninterrupted watching.
#
# Practice your `while` loop skills by simulating this "still watching" feature.
#
# The data is in the form of a list (`episodes`) of every Stranger Things episode, as well as a dictionary (`episode_lengths`) whose keys are the Stranger Things episode names and whose values are the episode lengths, in minutes.
#
# Your loop should continue until:
# * the user's response to the prompt is 'n' (not still watching)
# * or the user has watched all episodes in the series

# %%
# load the data
import sys
sys.path.append('./files')
from stranger_things import episodes, episode_lengths

# %%
# initialize variables 


# create a flag 


# while loop 
while
    # watch another episode 
    
    # update the total time spent watching TV
    
    # update the number of episodes watched
    
    # decide to prompt the user if they want to keep watching 

    # decide to update the keep_watching flag
