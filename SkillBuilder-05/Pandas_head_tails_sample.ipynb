# %%
# import libraries

# %%
# read in file

# %%
# Preview a DataFrame's first rows
# This is the most commonly used method to preview a DataFrame

# %%
# Preview a specified number of rows

# %%
# Preview the last rows

# %%
# Specify the number of rows to view

# %%
# This returns a random row from the DataFrame

# %%
# View a specified number of random rows
