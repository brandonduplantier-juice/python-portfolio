# %%
import pandas as pd

# %%
hulu = pd.read_csv('datasets/hulu.csv')

# %%
# Preview the first five rows of the DataFrame
# Each row has an associated index number to the left
hulu.head()

# %%
# Every row in the DataFrame has an associated index number
hulu.tail()

# %%
# A sampling of rows likewise shows indexing
hulu.sample(5)

# %%
# The index here is a sequence of integers from 0 up to (but not including) 1000

# %%
hulu.head()

# %%
# View rows based on range of index
# replace with col selection w/ brackets

# %%
# The .columns attribute returns column names
hulu.columns

# %%
# Use the bracket notation to select a column to view

# %%
# To select multiple columns, put column names inside a list.
