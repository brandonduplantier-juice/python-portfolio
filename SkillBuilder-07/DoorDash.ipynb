# %% [markdown]
# ![](https://logos-world.net/wp-content/uploads/2020/11/DoorDash-Emblem.png)

# %%
# import libraries 
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
# read in data
df = pd.read_csv('datasets/doordash_data.csv')
df.shape

# %%
# preview data
df.head(10)

# %%
# determine how many promo items there are

# %%
# determine how many promo orders there are

# %%
# create filter to subset to only promotions


# preview filtered data

# %%
# look at which store categories had the most promo codes

# %%
# create visualization of promo orders
