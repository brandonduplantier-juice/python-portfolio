# %% [markdown]
# # Let's go!!
#
# ![](https://media.giphy.com/media/zIOdLMZDcBDc2gk6vV/giphy.gif)

# %%
# import pandas and plotly express libraries

# %% [markdown]
# ### Effort 1 - Inspect your data!
#
# You're going to be working with data about chocolate bar ratings! In the `cacao.csv` file you will find the following information:
#
# * **Company**: Name of the company manufacturing the bar
# * **Bean Origin**: The specific geo-region of origin for the bar
# * **REF**: A value linked to when the review was entered in the system (higher = more recent)
# * **Review Date**: Date of publication of the review
# * **Cocoa Percent**: Cocoa percentage of the chocolate bar being reviewed
# * **Company Location**: Manufacturer base country
# * **Rating**: Expert rating for the bar
# * **Broad Bean Origin**: The country of origin for the cacao bean
#
# ![](https://media.giphy.com/media/XECiLxeHvwdD96Jc6Z/giphy.gif)

# %% [markdown]
# Load and preview the dataset in pandas

# %%
# load cacao.csv from the datasets folder


# preview dataframe

# %% [markdown]
# Examine the column names

# %%
# view column names

# %% [markdown]
# ### Effort 2 - Clean & Gather facts about your data!
#
# Examine column data types, DataFrame index, number of non-missing rows, etc.

# %%
# view information about the dataframe

# %% [markdown]
# Examine the statistical summaries of numerical columns

# %%
# View statistical summaries

# %% [markdown]
# Delete the REF column and preview the results

# %%
# drop the "REF" column

# %% [markdown]
# Examine the unique values in the `Company Location` column

# %%
# view unique values in "Company Location"

# %% [markdown]
# Examine the number of unique values in the `Company Location` column

# %%
# number of unique values in "Company Location"

# %%
# count how many times each value in "Company Location" appears

# %% [markdown]
# Examine the mean percentage of cocoa in chocolate from French companies

# %%
# Filter "Company Location" to companies based in France
# Calculate the mean of the "Cocoa Percent" column

# %% [markdown]
# Examine the mean percentage of cocoa in chocolate from Ghanaian companies (Ghana)

# %%
# Filter "Company Location" to companies based in Ghana
# Calculate the mean of the "Cocoa Percent" column

# %% [markdown]
# ## Level Up
#
# ![](https://media.giphy.com/media/IfshYVDl634yiET8JB/giphy.gif)

# %% [markdown]
# ### Visualize your data!
#
# Create a bar chart of the top 10 chocolate manufacturing countries, determined by the number of companies.

# %%
# Calculate the number of chocolate companies in each country.
# Keep the top 10
# Create bar chart
