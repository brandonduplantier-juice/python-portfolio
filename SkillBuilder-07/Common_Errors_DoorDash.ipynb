# %% [markdown]
# ![](https://logos-world.net/wp-content/uploads/2020/11/DoorDash-Emblem.png)

# %%
# import libraries 
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
# read in data
df = pd.read_csv('datasets/doordash_data.csv')

# %%
# preview data
df.head()

# %%
# determine how many promo items there are 
df['promo_item'].sum()

# %%
# determine how many promo orders there are
df['promo_order'].sum()

# %%
# Each filtering criterion needs to be enclosed within parentheses
promo_filter = 

# preview filtered data
df[promo_filter].sample(20)

# %%
# Each filter is enclosed within parentheses
promo_filter = (df['promo_item'] == 1) | (df['promo_order'] == 1)

# preview filtered data
df[promo_filter].sample(20)

# %%
# Specify the column when calling value_counts
df[promo_filter].value_counts()[:10]

# %%
# Column is now specified
# look at which store categories had the most promo code
