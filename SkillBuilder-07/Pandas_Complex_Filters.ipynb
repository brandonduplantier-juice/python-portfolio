# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/hulu.csv')
df.head()

# %%
# A row returns True if its rating is 4.5 or higher

# %%
# Filter for rows with a high rating

# %%
# A row returns True if its genre is "Comedy"

# %%
# Filters for rows whose genre is "Comedy"

# %%
# Filter for shows with a high rating AND shows that are comedies

# %%
# Filter for comedies or dramas

# %%
# Filter for comedies, dramas, or animes.

# %%
# Use .isin() to filter for multiple values of a column
