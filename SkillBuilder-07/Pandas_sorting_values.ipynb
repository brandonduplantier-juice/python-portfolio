# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/hulu.csv")

# %%
df.head()

# %%
# Sort the DataFrame by the number of seasons a show was on the air

# %%
# Sort in descending order

# %%
# Sort by multiple columns
