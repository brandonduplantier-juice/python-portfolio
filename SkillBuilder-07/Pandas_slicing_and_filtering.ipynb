# %%
import pandas as pd

# %%
# Read the data file into a DataFrame
df = pd.read_csv("datasets/HuluRaw.csv")

# %%
# Preview the DataFrame
df.head()

# %%
# Use .loc to access all rows and the first seven columns

# %%
# Use .loc to access all rows and the first seven columns
# Not specifying the row range returns all rows

# %%
# Pass a list to .loc to see specific non-sequential columns

# %%
# Use .iloc to access the same rows and columns
# Remember that .iloc is exclusive: it does not include the column at position 7

# %%
# Is the rating in each row greater than 4? If yes, True. If no, False.
# Pandas does this automatically for us! No need for a FOR loop!

# %%
# Apply a logical operator to filter the DataFrame
