# %%
# Assign a string to a variable

# %%
# Repeat a string ten times

# %%
# Adding a number to a string causes a TypeError

# %%
# Assign a string to another variable


# Add two strings together

# %%
# Subtracting a string from a string throws a TypeError

# %%
# Calling a variable that hasn't been declared causes a NameError

# %%
# Declaring the variable fixes the error

# %%
# Forgetting to close parentheses throws a SyntaxError

# %%
# Closing the parentheses fixes the error

# %%
# Forgetting to close curly braces in an f-string throws a SyntaxError

# %%
# Closing the curly braces fixes the error
