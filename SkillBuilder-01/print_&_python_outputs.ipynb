# %% [markdown]
# ### Part 1: Reviewing the print() function

# %% [markdown]
# ### Part 2: Cell output
#
# A variable or operation at the end of a cell is printed to screen as output

# %% [markdown]
# Variable assignments don't get printed as `Out`put.

# %% [markdown]
# Only the last variable or operation gets printed as output:

# %% [markdown]
# ### Part 3: f-strings
#
# Commas can be used in `print()` function calls to print multiple arguments on the same line.

# %% [markdown]
# Formatted strings (f-strings) can be used to more smoothly print strings and variables together.
