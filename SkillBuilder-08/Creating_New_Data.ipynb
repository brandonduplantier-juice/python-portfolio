# %%
# import library
import pandas as pd

# read in data
df = pd.read_csv('datasets/dunder_mifflin_sales.csv')

# %%
# Display data
print(df.shape)
df.head()

# %% [markdown]
# ### Simple Transformations

# %%
# Numeric Calculations

# %%
# String Calculations
# Create a new column with all of the relevant shipping info needed

# %%
# show address prints properly

# %% [markdown]
# ### DataFrames vs Series
#
# A **Series** in Pandas is one column of data or a table with only one column. A **DataFrame** in Pandas is a table with 2 or more columns, in other words, a collection of Series.

# %%
# A Series

# %%
# show Series

# %%
# A DataFrame

# %%
# Series and DataFrames, while similar, are NOT the same thing under the hood

# %%
# show DataFrame
df.head()

# %% [markdown]
# ### Transformations with User-Defined Functions

# %%
# Create function that takes in a Series

# %%
# Create function that takes in a dataframe

# %%
# Create new columns using the functions

# %%
# show results of function

# %%
# Calculate original profit

# %%
# Calculate profit for MSPC

# %%
# Calculate the number of sales each account manager has made

# %%
# Fill in Missing Values!
