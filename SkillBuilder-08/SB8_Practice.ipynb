# %% [markdown]
# # Training Time!
#
# ![](https://media.giphy.com/media/V0R2wB5DW64Q8/giphy.gif)

# %%
# import pandas and plotly express libraries

# %% [markdown]
# ### Effort 1 - Inspect your data!
#
# You are going to be working with data about the price of colleges / universities in each state from 2013-2021.
#
# Each state has the breakdown for `Fees/Tution` and `Room/Board` cost each year for the 3 types of costs for both 2-year and 4-year schools:
#
# - `Private`
# - `Public In-State`
# - `Public Out-of-State`

# %% [markdown]
# Load the dataset and preview the first five rows.

# %%
# Load the school_expenses.csv from the datasets folder 


# preview the data

# %% [markdown]
# Print statistical summaries of numerical columns.

# %%
# Print statistical summaries of numerical columns

# %% [markdown]
# Print information regarding DataFrame columns, e.g. data type of each column

# %%
# Print info on columns

# %% [markdown]
# In the cell below, `cols` is a list of all columns that are categorical.
# Complete the for-loop to print the number of occurrences of each unique value in each column.

# %%
# Run this cell! (Do not modify)
# this code first gets a list of column names, then drops the 'Value' label, 
# and stores it all as a list (rather than an array)
cols = df.columns.drop('Value').tolist()
cols

# %%
# Print the number of occurrences of each unique value for every column in the `cols` list created above
# hint: use a for loop to iterate over each column name and use the method that counts each unique value
# Use print(f'Column name: {col}') before each call to the method to organize the output
# Use the print('\n') to print a new line after each loop to make it easier to read the output

# %% [markdown]
# ### Effort 2 - Gather facts and visualize your data!
#
# Filter for only `Fees/Tuition` in the `Expense` column. Assign the results to a new variable called `fees_tuition`. Randomly sample 15 rows from the new DataFrame.

# %%
# Return only rows that contain Fees/Tuition data in the Expense column

# randomly sample 15 rows

# %% [markdown]
# What is the average Fees/Tuition in each type of institution, i.e. Private, Public In-State, and Public Out-of-State?

# %%
# Return the average Fees/Tuition of each `type` of school
# hint: use grouping

# %% [markdown]
# Create a bar chart of the average Fees/Tuition by type of institution

# %%
# Bar chart of average Fees/Tuition by school type
# It is better to store this as a separate dataframe first before plotting

# %% [markdown]
# What is the average Fees/Tuition in schools by state? <br>
# Sort the results in ascending order.

# %%
# Average Fees/Tuition by state
# Note you can "chain" methods in Pandas! 
# This reduces the amount of intermediate variables needed
# e.g. df.groupby(col).agg(agg_dict).sort_values()

# %% [markdown]
# Now group the DataFrame by state, and examine both the mean and median Fees/Tuition value of each state. Are the two values very different for any of the states?

# %%
# Mean and median values of Fees/Tuition by state

# %% [markdown]
# ## Level Up
#
# ![](https://media.giphy.com/media/KcKAiYMbLMdGS8KsB3/giphy.gif)

# %% [markdown]
# Now let's stratify, or break down, the average tuition by state AND by school type. Sort the results in ascending order. Which state has the cheapest Public In-State tuition overall? Which state has the most expensive Private schools?

# %%
# Average Fees/Tuition of each type of school per state
