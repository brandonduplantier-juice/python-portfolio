# %% [markdown]
# # Nike & Adidas & `.groupby()`

# %% [markdown]
# Data for Nike and Adidas footware sales are stored in a .csv file named `nike_adidas.csv`. Use the `.groupby()` method to report on the local running store's customer market.

# %%
# import library 
import pandas as pd

# load the data 
df = pd.read_csv()

# preview the data

# %%
# total revenue from all products

# %% [markdown]
# ### The `.groupby()` method on a single feature

# %%
# total revenue for Nike and Adidas products

# %%
# average price of Nike and Adidas products

# %% [markdown]
# ### The `.groupby()` method on multiple features

# %%
# preview the data (again)

# %%
# total revenue by brand AND price category

# %%
# average discount by brand AND price category
