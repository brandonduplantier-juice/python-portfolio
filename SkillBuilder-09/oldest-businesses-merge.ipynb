# %% [markdown]
# # The Oldest Businesses in the World
# ### And The `pd.merge()` Method

# %% [markdown]
# BusinessFinancing.co.uk researched the oldest companies still in business in almost every country. Results are stored in datasets named `businesses.csv`, `countries.csv`, and `categories.csv`.
#
# Let's explore some of the world's oldest businesses still in operation.

# %%
# import library

# load data 


# preview data

# %%
# the oldest businesses in the world

# %%
# merge businesses + countires

# %% [markdown]
# ## LevelUp:
# Remember our oldest business in the world, Kongō Gumi? We know Kongō Gumi was founded in the year 578 in Japan, but it's a little hard to decipher which industry it's in. Information about what the category_code column means is in the dataset named `categories.csv`.
#
# Can you merge `businesses` with `categories` to find out how many of the world's oldest businesses are in each category of industry?
