# %% [markdown]
# # Iron Man 1 and Iron Man 2
# You have two datasets with a list of actors and characters from Iron Man 1 and Iron Man 2. Which actors *did not* play a role in both movies?
#
# Actors in Iron Man 1 are in the file `iron_man_1.csv`; actors in Iron Man 2 are in the file `iron_man_2.csv`

# %%
# import library


# load data 


# preview data

# %%
# merge dataframes 

# preview dataframe

# %%
# who did not act in both movies
