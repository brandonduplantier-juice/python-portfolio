# %% [markdown]
# ![](https://media.giphy.com/media/d3mlE7uhX8KFgEmY/giphy.gif)

# %% [markdown]
# ### Working with Data Joins

# %%
# libraries
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# read in revenue data
revenue_df = pd.read_csv('datasets/customer_revenue.csv')
revenue_df.shape

# %%
# read in email campaigns
campaigns = pd.read_csv('datasets/email_campaigns.csv')
campaigns.shape

# %%
# preview data
revenue_df.head()

# %%
# preview data
campaigns.head()

# %% [markdown]
# #### Revenue Analysis
#
# You want to analyze the revenue performance for each of the marketing campaigns.
#
# **KPIs:**
# * Total Revenue per Campaign
# * Average Revenue per Campaign
#
# Note: Customers who did not make a purchase are not included in the KPIs
#
#
# **Questions**
# * which dataframe is your _leading_ table?
# * what type of join will you use?
#
# hint: We are _only_ interested in customers who have made purchases

# %%
# join data for revenue analysis

# %%
# preview joined data

# %%
# aggregate the data
# calculate the total revenue per campaign and the average customer spend

# %% [markdown]
# #### Campaign Analysis
#
# You want to determine which, if any, marketing campaigns are underperforming.
#
# **KPIs:**
# * Conversion Rate
# * Average Revenue per Campaign
# * Total Revenue per Campaign
#
# Note: Customers who did not make a purchase should have a revenue of $0 and are included in the KPIs
#
#
# **Questions**
# * which dataframe is your _leading_ table?
# * what type of join will you use?
#
# hint: We are interested in _all_ customers, regardless if they have made a purchase or not.

# %%
# Create a column for those who made a purchase

# %%
# Join data for campaign analysis

# %%
# fill in missing values for customers who did not make a purchase

# %%
# aggregate the data
# calculate the total revenue per campaign, average customer spend, and the conversion rate

# %% [markdown]
# ## Questions to ask before joining data
# * What is the _focus_ of my analysis?
# * How will the additional data help me achieve that analysis?
