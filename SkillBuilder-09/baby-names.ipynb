# %% [markdown]
# # Popular Baby Names in the United States

# %% [markdown]
# For each year, from 2000 to 2021, the Social Security Administration publishes the top 1000 most popular baby names for American babies. These popular babies names are stored in .csv files, separated by year:
# > `yob2000.csv` <br/>
# > `yob2001.csv` <br/>
# > `yob2002.csv` <br/>
# > `yob2003.csv` <br/>
# > ...

# %% [markdown]
# Starting with just two years, combine the most popular baby names in the United States from 2000 and 2001 into a single DataFrame using the `pd.concat()` method.

# %%
# import library: 


# load data


# preview data

# %%
# combine dataframes into one single dataframe

# %% [markdown]
# Next, we'll combine *all* baby names data into a single dataframe. Using a `for` loop will be key here!
